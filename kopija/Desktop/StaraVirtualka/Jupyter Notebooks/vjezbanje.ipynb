# %%
import numpy as np
import time

# %%
time.asctime(time.localtime())
# Out:
# 'Wed Apr 22 22:25:17 2020'

# %%
np.array([1,2,3,4]).shape
# Out:
# (4,)

# %%
arr=[np.random.uniform(0,x,1000000),np.random.uniform(0,x,1000000)]

# %%
x=2

# %%
a=1+2j

# %%
a.real
# Out:
# 1.0

# %%
a=np.array([1,2,3])

# %%
b=np.array([1,2])

# %%
rad=np.array([2,6])

# %%
a=[[1,1],[1,0.5,1],[0,0.5,1]]

# %%
a[0:1][0:]
# Out:
# [[1, 1]]

# %%
a[1:][0][:]
# Out:
# [1, 0.5, 1]

# %%
n=a[1:]

# %%
n
# Out:
# [[1, 0.5, 1], [0, 0.5, 1]]

# %%
n=np.array(n)

# %%
n
# Out:
# array([[1. , 0.5, 1. ],
#        [0. , 0.5, 1. ]])

# %%
n[:,0]
# Out:
# array([1., 0.])

# %%
a=np.random.uniform(0,1,10)+np.random.uniform(0,2,10)*1j

# %%
a
# Out:
# array([0.23252481+1.90893191j, 0.82818092+0.69696657j,
#        0.43283776+1.94762111j, 0.83250053+1.37334688j,
#        0.577358  +1.76229163j, 0.68766112+0.37364659j,
#        0.03476538+0.88242895j, 0.14879553+1.49275053j,
#        0.63588494+1.98393408j, 0.78711949+0.37609922j])

# %%
for i in a:
    print(i)
# Out:
# (0.232524807739232+1.9089319109387317j)
# (0.8281809211606934+0.6969665719641522j)
# (0.4328377592851962+1.947621106147699j)
# (0.8325005327382566+1.3733468848690162j)
# (0.5773580021895104+1.7622916313291195j)
# (0.6876611244002158+0.37364659177450354j)
# (0.03476538183312006+0.8824289532085201j)
# (0.14879553165543002+1.4927505300639232j)
# (0.6358849432596084+1.9839340822173994j)
# (0.7871194883026232+0.37609922055849876j)

# %%
import pandas as pd

# %%
tecaj=pd.read_json('ProsjeciMjesecni_2011-2020.json')

# %%
tecaj.head()
# Out:
#    Godina    Mjesec      Država  Šifra valute Valuta  Jedinica  \
# 0    2011  Siječanj  Australija            36    AUD         1
# 1    2011  Siječanj      Kanada           124    CAD         1
# 2    2011  Siječanj       Češka           203    CZK         1
# 3    2011  Siječanj      Danska           208    DKK         1
# 4    2011  Siječanj    Mađarska           348    HUF       100
#
#   Kupovni za devize Srednji za devize Prodajni za devize
# 0          5,504948          5,521513           5,538077
# 1          5,554872          5,571587           5,588302
# 2          0,301385          0,302292           0,303199
# 3          0,989672          0,992650           0,995628
# 4          2,676801          2,684856           2,692910

# %%
tecaj['Država']
# Out:
# 0                Australija
# 1                    Kanada
# 2                     Češka
# 3                    Danska
# 4                  Mađarska
#                ...
# 1562                    SAD
# 1563
# 1564    Bosna i Hercegovina
# 1565                    EMU
# 1566                Poljska
# Name: Država, Length: 1567, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
plt.rcParams['figure.max_open_warning'] = 50
# %matplotlib agg
# %matplotlib -l
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Proba')
ax1.plot([1, 2, 3], [5, 7, 2])
ax1.plot([3, 4, 2, 0], [1, 8, 3, 4])
fig1

# %%
ax1.plot([3, 5, 5], [-1, 1, 3], color='red', marker='o')

# %%
fig1

# %%
fig6, ((gl, gs, gd), 
       (dl, ds, dd)) = plt.subplots(2, 3)
fig6.tight_layout()
x = np.linspace(0, 7)
xbez0 = x[1:]
gl.plot(x, 1/x)
gs.plot(x, x)
gd.plot(x, np.cos(x))
dl.plot(np.sin(x), np.cos(x))
ds.plot(x, np.exp(x))
dd.plot(xbez0, np.log(xbez0))
fig6
# Out:
# /home/obj/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide

# %%
dijagonalna = np.diag([2, 3, 5, -1])
figmat, axmat = plt.subplots()
axmat.imshow(dijagonalna, cmap='gray')
figmat

# %%
with plt.xkcd():
    figxkcd, axkcd = plt.subplots()
    x = np.linspace(-1, 2*np.pi, 100)
    axkcd.plot(x, x*np.cos(x))
    axkcd.annotate('ishodište', (0, 0), (0, -2), 
                   arrowprops=dict(arrowstyle='->', color='red'))
figxkcd
# Out:
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Neue', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
from mpl_toolkits import mplot3d
fig3d, ax3d = plt.subplots(subplot_kw=dict(projection='3d'))
x, y = np.meshgrid(np.linspace(-2, 2), np.linspace(0, 4))
z = np.cos(x + np.sqrt(y))
ax3d.plot_surface(x, y, z, cmap='terrain', linewidth=1)
fig3d
